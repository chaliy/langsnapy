# %%
from pathlib import Path
from langsnapy import Project, Case

prj = Project(
    snapshot_folder_path=Path("./local-snapshots")
)

prj.compare_snapshots_by_run_ids(["bedrock", "openai"])
# Out:
# <table style="text-align:left; width: 100%; table-layout: fixed"><tr>
#             <td style="text-align:left; vertical-align:top;">
#                 <ul>
# <li><strong>llm_type:</strong> amazon_bedrock</li>
# <li><strong>model:</strong> anthropic.claude-v2:1</li>
# <li><strong>model_args:</strong> {'temperature': 0}</li>
# <li><strong>time_stamp:</strong> 2023-12-16 14:08:40.820761</li>
# </ul>
#
#             </td>
#
#             <td style="text-align:left; vertical-align:top;">
#                 <ul>
# <li><strong>llm_type:</strong> openai-chat</li>
# <li><strong>model:</strong> gpt-4</li>
# <li><strong>model_args:</strong> {}</li>
# <li><strong>time_stamp:</strong> 2023-12-16 14:09:02.825957</li>
# </ul>
#
#             </td>
#             </tr><tr>
#                 <td style="text-align:left;" colspan="2">
#                     <b>Inquiry: Привіт Петре! Як справи?</b>
#                 </td>
#             </tr><tr>
# ...
